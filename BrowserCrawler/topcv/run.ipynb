# %%
import get_job_url
# Out:
# Page load:1
# Page load:2
# Page load:3
# Saving job urls to json
# DONE !

# %%
import sys
sys.path.append('topcv/data')
sys.path.append('data')
print(sys.path)
# Out:
# ['d:\\Coding\\HCMUS\\DSa\\BrowserCrawler\\topcv', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\python311.zip', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\DLLs', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv', '', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\win32', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\Pythonwin', 'topcv/data', 'data']

# %%
import urls_not_exist

# %%
cd topcv
# Out:
# d:\Coding\HCMUS\DSa\BrowserCrawler\topcv\topcv

# %%
# !scrapy crawl topcv_i4_crawler -o json/out.json
# Out:
# ['Lập Trình Viên', 'Back-End (NestJS) 2 Năm Kinh Nghiệm (Lương 20-30 Triệu)', 'Mức lương', '20 - 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 26/04/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ['Front-End', 'Developer', ', Lương Từ 25-50 Triệu', 'Mức lương', '25 - 50 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '4 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 05/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ['Nhân Viên Kỹ Thuật', 'Truyền Hình Cáp - Không Yêu Cầu Kinh Nghiệm ( TP. Thủ Đức, TP. Đồng Xoài - Bình Phước, Bình Dương )', 'Mức lương', '7 - 10 triệu', 'Địa điểm', 'Bình Dương & 2 nơi khác', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 29/04/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ...

# %%
# !python json/format_out_data.py
