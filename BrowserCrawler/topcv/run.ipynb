# %%
import get_job_url
# Out:
# Page load:1
# Page load:2
# Page load:3
# Saving job urls to json
# DONE !

# %%
import sys
sys.path.append('topcv/data')
sys.path.append('data')
print(sys.path)
# Out:
# ['d:\\Coding\\HCMUS\\aDS\\applied-data-science\\BrowserCrawler\\topcv', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\python311.zip', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\DLLs', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv', '', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\win32', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\PC\\anaconda3\\envs\\DSAIenv\\Lib\\site-packages\\Pythonwin', 'topcv/data', 'data']

# %%
import urls_not_exist

# %%
cd topcv
# Out:
# d:\Coding\HCMUS\aDS\applied-data-science\BrowserCrawler\topcv\topcv

# %%
# !scrapy crawl topcv_i4_crawler -o json/out.json
# Out:
# ---------------------------------
# ['Trợ Lý Phiên Dịch Dự Án Phần Mềm (Thành Thạo', 'Tiếng Trung', ')', 'Mức lương', '14 - 22 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Game Coordinator (Fluent In Chinese)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 23/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Full Stack', 'PHP', 'Thu Nhập Từ 25,000,000 - 35,000,000 Triệu/Tháng', 'Mức lương', '25 - 35 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 22/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['System Engineer', '/ System Admin', 'Mức lương', '18 - 35 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['IT Support', 'Shopify Fulltime (Chia Ca Linh Hoạt, Có HTML/CSS, Tiếng Anh Tốt, Thu Nhập 8-12M+Thưởng)', 'Mức lương', '8 - 12 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 22/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên SEO', 'Website', 'Mức lương', '9 - 15 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 22/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Software Developer', '(Japan Onsite) Thu Nhập Cao Hấp Dẫn', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Nước Ngoài', 'Kinh nghiệm', '2 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Lập Trình Viên', '- Middle Odoo Developer - Lương Upto 30M - Đi Làm Ngay', 'Mức lương', 'Tới 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 09/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Kỹ Sư Thiết Bị CNTT - Thu Nhập 20 - 40 Triệu', 'Mức lương', '20 - 40 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 08/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Quản Lý Giải Pháp Kiêm', 'IT Support', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 26/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['IT B2B Marketer', 'Mức lương', '20 - 35 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '4 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 17/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Phát Triển Thị Trường', '(Nam)', 'Mức lương', 'Tới 17 triệu', 'Địa điểm', 'Hồ Chí Minh, Hà Nội', 'Kinh nghiệm', '1 năm', 'TopCV chưa hỗ trợ xem số lượt ứng tuyển cho việc làm này', 'Hạn nộp hồ sơ: 10/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['2D Motion', 'Graphic Designer', '- Level Fesher (Lương 7-10 Triệu + Phụ Cấp)', 'Mức lương', '7 - 10 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 22/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Business Analyst', '- Phân Tích Nghiệp Vụ Phần Mềm', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Business Analyst', '(Junior/Middle)', 'Mức lương', '12 - 16 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Solution Architect', '(SA)', 'Mức lương', '25 - 50 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Trên 5 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên', 'Nhân Sự', 'Tổng Hợp', 'Mức lương', '12 - 16 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Trưởng Nhóm', 'Nhân Sự', 'Mức lương', '15 - 20 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '5 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Hỗ Trợ Quản Lý Dự Án', 'Tiếng Nhật', 'Mức lương', 'Trên 12 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Nghiệp Vụ', 'Tiếng Nhật', 'Mức lương', 'Trên 10.8 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Game Product Owner', 'Mức lương', '1,000 - 1,500 USD', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên C&B', 'Mức lương', '15 - 18 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Java Developer', '(Từ 3.5 Năm Kinh Nghiệm)', 'Mức lương', 'Tới 45 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Manual', 'Tester', 'Mức lương', '8 - 12 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Golang', 'Developer', '(Middle/Senior)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Python', 'Developer', 'Mức lương', 'Tới 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['DevOps Engineer', '(Senior)', 'Mức lương', 'Tới 60 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['QC Engineer (Game)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên', 'Game Designer', 'Mức lương', '15 - 20 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Java Developer', '(English)', 'Mức lương', 'Tới 2,500 USD', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['DevOps Engineer', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Technical Artist', 'Mức lương', 'Tới 40 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Chăm Sóc Khách Hàng', '(Trực Tổng Đài)', 'Mức lương', '8 - 12 triệu', 'Địa điểm', 'Hà Nội, Hồ Chí Minh', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Network Engineer Intern', 'Mức lương', '2 - 3 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nodejs', 'Developer - IT Outsource Company', 'Mức lương', 'Tới 1,500 USD', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 29/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên Kiểm Soát Chất Lượng Từ 1-3 YOE (ITO)', 'Mức lương', 'Tới 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Data Analyst', 'Leader', 'Mức lương', '25 - 39 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Lập Trình Viên', 'Back-End', 'Mức lương', '9 - 11 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên', 'Tester', 'Mức lương', '12 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['IT Communicator', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên', 'Phân Tích Nghiệp Vụ', 'Mức lương', '8 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 06/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Data Engineer', '- Upto 30M Gross', 'Mức lương', '20 - 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Blockchain', 'Developer', 'Từ 6 Tháng Kinh Nghiệm', 'Mức lương', '18 - 28 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên IT', 'Support/Helpdesk', 'Mức lương', '8 - 10 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên Đảm Bảo Chất Lượng (', 'Pqa', ')', 'Mức lương', 'Tới 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Smart Contract', 'Developer', 'Mức lương', '2,500 - 3,000 USD', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Kỹ Sư Lập Trình', 'Vision (C#)', 'Mức lương', '8 - 15 triệu', 'Địa điểm', 'Hải Phòng', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Manual', 'Tester', '(Web/App) - Kỹ Sư Kiểm Thử', 'Mức lương', '20 - 35 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Thực Tập Sinh', 'Phân Tích Dữ Liệu', 'Mức lương', 'Tới 3 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['PHP Developer', '(English Proficiency)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Video Editor', 'Mức lương', '8 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['NodeJS', 'Developer', 'Mức lương', '17 - 22 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Chăm Sóc Khách Hàng', 'Mức lương', '10 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Test Lead', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '5 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['HR Intern', 'Mức lương', '4 - 5 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['QC Engineer', 'Mức lương', '20 - 26 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Backend Developer', 'Mức lương', 'Tới 25 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Fresher', 'Backend Engineer', '.', 'Mức lương', '10 - 18 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Fresher', 'Tester', 'Mức lương', '9 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên SEO', 'Website', 'Mức lương', '14 - 20 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Net Fullstack Định Hướng Tech Lead', 'Mức lương', '20 - 30 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Fullstack (NodeJS + ReactJS/', 'Java', ')', 'Mức lương', '25 - 50 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '4 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Junior', 'Tester', 'Mức lương', '7 - 15 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Lập Trình Viên', 'Appscript-Appsheet', 'Mức lương', '9 - 11 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Software', 'Tester', 'Mức lương', 'Tới 1,000 USD', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Product Game ( Thời Vụ 3 Tháng)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Digital Tech Support Executive', 'Mức lương', '15 - 20 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Fresher', 'Tester', 'Mức lương', '3 - 5 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên Điều Phối', 'Dự Án', 'Mức lương', '8 - 10 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Trưởng Nhóm Pháp Chế', 'Mức lương', '25 - 35 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '5 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Business Analyst', '(BA)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên QC Phần Mềm', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Sự', 'Quản Lý Và Phát Triển Youtube', 'Mức lương', '5 - 10 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Backend Developer', '(Lập Trình Viên Backend)', 'Mức lương', '15 - 25 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên SEO', 'Website', 'Mức lương', '8 - 13 triệu', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Chuyên Viên Quản Trị Dự Án Cho Team Sản Phẩm', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '3 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 31/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Junior', 'Frontend Developer', '(Angular)', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hồ Chí Minh', 'Kinh nghiệm', '2 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['TTS Front-End', 'Developer', 'Mức lương', 'Trên 1 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Lập Trình Viên .Net', 'Mức lương', '20 - 35 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '4 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 23/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Nhân Viên', 'Designer', 'Mức lương', '9 - 12 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Dưới 1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['Thực Tập Sinh Vận Hành Hệ Thống -', 'System Engineer', 'Mức lương', 'Thoả thuận', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', 'Không yêu cầu kinh nghiệm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 25/05/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# ---------------------------------
# ['IT', 'Project Manager', '(PM IT)', 'Mức lương', '15 - 25 triệu', 'Địa điểm', 'Hà Nội', 'Kinh nghiệm', '1 năm', 'Xem số người đã ứng tuyển', 'New', 'Hạn nộp hồ sơ: 30/06/2024', 'Ứng tuyển ngay', 'Lưu tin', 'Ứng tuyển lại', 'Nhắn tin']
# ---------------------------------
# 2024-04-23 22:54:09 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: topcv)
# 2024-04-23 22:54:09 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.11.8 | packaged by Anaconda, Inc. | (main, Feb 26 2024, 21:34:05) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.5, Platform Windows-10-10.0.22631-SP0
# 2024-04-23 22:54:09 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-04-23 22:54:09 [asyncio] DEBUG: Using selector: SelectSelector
# 2024-04-23 22:54:09 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-04-23 22:54:09 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2024-04-23 22:54:09 [scrapy.extensions.telnet] INFO: Telnet Password: d8c2a5ff058d86ca
# 2024-04-23 22:54:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-04-23 22:54:10 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'topcv',
#  'CONCURRENT_REQUESTS': 1,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'CONCURRENT_REQUESTS_PER_IP': 1,
#  'DOWNLOAD_DELAY': 2,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'topcv.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'RETRY_HTTP_CODES': [429],
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['topcv.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}
# 2024-04-23 22:54:10 [faker.factory] DEBUG: Not in REPL -> leaving logger event level as is.
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Error loading User-Agent provider: scrapy_fake_useragent.providers.FakeUserAgentProvider
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Unable to load any of the User-Agent providers
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Using '<class 'scrapy_fake_useragent.providers.FixedUserAgentProvider'>' as the User-Agent provider
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Error loading User-Agent provider: scrapy_fake_useragent.providers.FakeUserAgentProvider
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Unable to load any of the User-Agent providers
# 2024-04-23 22:54:10 [scrapy_fake_useragent.middleware] INFO: Using '<class 'scrapy_fake_useragent.providers.FixedUserAgentProvider'>' as the User-Agent provider
# 2024-04-23 22:54:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy_fake_useragent.middleware.RandomUserAgentMiddleware',
#  'scrapy_fake_useragent.middleware.RetryUserAgentMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-04-23 22:54:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-04-23 22:54:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-04-23 22:54:10 [scrapy.core.engine] INFO: Spider opened
# 2024-04-23 22:54:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-04-23 22:54:10 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-04-23 22:54:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/robots.txt> (referer: None)
# 2024-04-23 22:54:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/tro-ly-phien-dich-du-an-phan-mem-thanh-thao-tieng-trung/1312779.html?ta_source=ITJobs_LinkDetail> (referer: None)
# 2024-04-23 22:54:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/tro-ly-phien-dich-du-an-phan-mem-thanh-thao-tieng-trung/1312779.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Trợ Lý Phiên Dịch Dự Án Phần Mềm (Thành Thạo', 'Tiếng Trung', ')'], 'company_name': 'CÔNG TY TNHH PHÁT TRIỂN VĂN HÓA CÔNG NGHỆ INTERNET ATG', 'address': ['Tầng 6, Victory Tower, số 12 đường Tân Trào, Phường Tân Phú, Quận 7, Hồ Chí Minh'], 'salary': ['14 - 22 triệu'], 'exp': 'Hồ Chí Minh', 'remaining': '23/05/2024', 'Mô tả công việc': ['- Phụ trách dịch thuật trong các cuộc họp và tài liệu cho các dự án phần mềm của công ty, đảm bảo dịch thuật chính xác các thuật ngữ kỹ thuật;', '- Phụ trách liên lạc trao đổi thông tin đối nội và đối ngoài về các dự án phần mềm để đảm bảo dự án vận hành suôn sẻ;', '- Hỗ trợ người phụ trách dự án thực hiện và hoàn thành các nhiệm vụ khác nhau của dự án phần mềm.'], 'Yêu cầu ứng viên': ['- Giới tính: Ưu tiên nữ, Độ tuổi 26-36 tuổi', '- Đã học qua chuyên ngành tiếng Trung, thông thạo tiếng Trung, nghe, nói, đọc, viết, thành thạo song ngữ Trung - Việt', '- Ứng viên có kinh nghiệm làm việc tại công ty về internet hoặc phát triển phần mềm', '- Am hiểu ngành Internet và các thuật ngữ kỹ thuật liên quan đến lập trình máy tính, phát triển phần mềm.', '- Chủ động, tận tâm, tỉ mỉ trong công việc, có khả năng giao tiếp, hiểu biết, chấp hành và chịu áp lực tốt.', '- Để ứng tuyển vào vị trí này, vui lòng gửi CV bằng tiếng Trung hoặc Song Ngữ Trung Việt.'], 'Quyền lợi': ['- Mức lương: 14 triệu - 22 triệu/ tháng (thỏa thuận theo năng lực)', '- Phúc lợi: Hỗ trợ tiền ăn trưa và tiền gửi xe 660.000vnd, thưởng chuyên cần 500.000vnd', '- Thời gian thử việc : 1-2 tháng', '- Hưởng các chế độ BHXH, nghỉ phép theo quy định của Luật lao động & Công ty.', '- Quà sinh nhật/ trái cây hàng tuần/ đồ ăn nhẹ hàng ngày', '- Thưởng lễ, tết, lương tháng thứ 13', '- Liên hoan, vui chơi định kì, Du lịch, nghỉ dưỡng, teambuilding do công ty tổ chức'], 'Địa điểm làm việc': ['- Hồ Chí Minh: Tầng 6, Victory Tower, số 12 đường Tân Trào, Phường Tân Phú, Quận 7'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 09:00 đến 18:00)', 'Nghỉ trưa 1,5 tiếng. Thứ 7 làm việc cách tuần'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '1 năm', 'Số lượng tuyển': '2 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 22:54:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/game-coordinator-fluent-in-chinese/1311450.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/tro-ly-phien-dich-du-an-phan-mem-thanh-thao-tieng-trung/1312779.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 22:54:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/game-coordinator-fluent-in-chinese/1311450.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Game Coordinator (Fluent In Chinese)'], 'company_name': 'CÔNG TY TNHH ATHENA STUDIO', 'address': ['40A Lam Sơn, Phường 2, Quận Tân Bình, Thành phố Hồ Chí Minh, Việt Nam'], 'salary': ['Thoả thuận'], 'exp': '1 năm', 'remaining': '23/06/2024', 'Mô tả công việc': ['Receives, exchanges information, and compiles plans from functional departments within the executive team.', 'Translates documents describing features and facilitates communication during partner meetings.', 'Communicates with partners via various means (chat, email, phone) under the guidance of superiors.', 'Monitors and oversees the progress of implementing plans established by partners and the executive team.', 'Builds, maintains, and records the history of work exchange between the two parties for future reference.', 'Reminds and ensures partners and executive teams adhere to proper plan implementation.', 'Compiles reports on product sales results and sends them to partners to provide valuable data for strategic decision-making.', 'Responsible for translation and interpretation in telephone meetings and meetings between the company and partners.', 'Gains experience and knowledge about partner game versions in advance, and supports new game research when needed.', 'Participates in the entire game lifecycle, from purchasing games to publishing and operating them.'], 'Yêu cầu ứng viên': ['SKILLS', 'At least 1-3 years of experience in coordination/project management within game industry', 'Proficient in Chinese and intermediate in English', 'Strong organizational skills with the ability to prioritize tasks, manage multiple deadlines, and maintain detailed records.', 'Ability to build rapport with players, partners, and colleagues, fostering positive working relationships.', 'Ability to thrive in a fast-paced environment and adapt to changing priorities.', 'KNOWLEDGE', 'Familiarity with game development processes (preferred).', 'Understanding of gaming principles and mechanics (preferred).', 'ABILITIES', 'Manage time effectively and meet deadlines consistently.', 'Think critically and make sound decisions in pressure situations.', 'Take initiative and demonstrate a proactive approach to problem-solving.', 'Learn quickly and adapt to new technologies and procedures.'], 'Quyền lợi': ['Professional, creative working environment and talented teams, equal opportunities & agile culture', 'Great facility to work. You will have a MacBook and extra high-definition screens', 'Electrical standing desk for the most comfortable seat', 'Annual leave 12 days / sick leave 2 days / remote work 12 days/anniversary leave 1 day', 'Paternity Leave policy offers more than 10 days of Paid leave, not including days off.', 'Remaining Annual leave will be transferred to the next working year', 'Premium health insurance package for you and your relatives', 'Annual health check-up at premium clinic', 'Interesting workout activities: gym/fitness, yoga, kickboxing, football after work', 'Annual bonus and project bonus', 'Reward program for engaged activities and volunteering', 'Annual company trip & quarter team bonding activities', 'Happy hours and awesome parties', 'Development opportunity: sponsorship for training courses', 'With regular discussions, you will have a lot of opportunities to learn from experts in their fields', 'International opportunity to expose and grow', 'At least one abroad travels every year. We often send our elites to international conferences like GDC, WWDC, Google I/O... to update the latest technology', 'Additional allowance & gifts for birthdays, giving-birth, weddings, illness, Mid-Autumn Festival, Lunar New Year, 1/1, 1/5, 1/6...', 'Pantry booster with food & beverages, game station & entertainment: PS4,...'], 'Địa điểm làm việc': ['- Hồ Chí Minh: 40A Lam Sơn, Phường 2, Quận Tân Bình, Thành phố Hồ Chí Minh, Tân Bình'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghi ...
# 2024-04-23 22:54:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/full-stack-php-thu-nhap-tu-25-000-000-35-000-000-trieu-thang/1309834.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/game-coordinator-fluent-in-chinese/1311450.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 22:54:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/full-stack-php-thu-nhap-tu-25-000-000-35-000-000-trieu-thang/1309834.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Full Stack', 'PHP', 'Thu Nhập Từ 25,000,000 - 35,000,000 Triệu/Tháng'], 'company_name': 'CÔNG TY TNHH KIN LONG VIỆT NAM', 'address': ['Tầng 3 TTTM, tòa nhà CTM Complex, số 139 Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấy, Hà Nội'], 'salary': ['25 - 35 triệu'], 'exp': 'Hà Nội', 'remaining': '22/05/2024', 'Mô tả công việc': ['- Tham gia vào quá trình phát triển hệ thống Thương mại điện tử và hệ thống nghiệp vụ nội bộ', '- Viết API cho mobile app, nhận API từ bên thứ 3 và các hệ thống khác trong tập đoàn (kỹ năng Backend)', '- Thực hiện phát triển một số module các nền tảng liên quan đến JS (kỹ năng Frontend)', '- Đóng góp ý kiến, giải pháp, phản biện các vấn đề kỹ thuật và nghiệp vụ', '- Lên kế hoạch và thực hiện theo sprint, tháng, quý trong năm', '- Tham gia xây dựng/ hoàn thiện quy trình phát triển sản phẩm của Công ty'], 'Yêu cầu ứng viên': ['- Có kiến thức tốt và thành thạo về OOP, Clean architecture', '- Có trên 1 năm kinh nghiệm PHP bao gồm Yii2 hoặc Laravel', '- Hơn 1 năm kinh nghiệm với MySQL hoặc MongoDB', '- Hơn 1 năm kinh nghiệm với lập trình front-end, thành thạo HTML, CSS, Javascript hoặc Typescript. Đã sử dụng một trong các Framework Vuejs, Angular, React', '- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu code', '- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu hệ thống', '- Có kinh nghiệm trong việc phân tích, thiết kế, tối ưu DB', '- Tiếng Anh giao tiếp cơ bản (để thuận lợi khi cần phải đi công tác nước ngoài hoặc giao lưu trao đổi với các team khác của các quốc gia có sử dụng tiếng Anh)', '- Thành thạo GIT', '- Ưu tiên ứng viên có kinh nghiệm sử dụng Scrum trong quá trình làm việc', '- Ưu tiên ứng viên có kinh nghiệm làm việc trong công ty product với các techstack phức tạp', '- Ưu tiên có kinh nghiệm về Ecommerce hoặc Payment', '- Ưu tiên Yii2 Framework'], 'Quyền lợi': ['- Lương hấp dẫn từ 25,000,000 - 35,000,000 Triệu/Tháng', '- Lương thử việc được trả 100%, thời gian thử việc được tính nghỉ phép', '- Phụ cấp tiền ăn trưa, xăng xe, chi phí liên lạc điện thoại', '- Được hưởng các chế độ thưởng chuyên cần, thưởng hiệu suất làm việc, thưởng thâm niên công tác...', '- Xét tăng lương 1 lần / năm theo quy định của công ty', '- Được tham gia BHYT + BHXH + BHTN và các chế độ phúc lợi xã hội khác theo luật lao động Việt Nam', '- Được hưởng chế độ nghỉ Lễ, tết theo quy định của Luật Lao động và Quy định của công ty.', '- Được làm việc trong môi trường năng động, chuyên nghiệp, được cử sang nước ngoài đào tạo', '- Được tham gia các hoạt động chung của Công ty: du lịch, teambuilding, sự kiện.........'], 'Địa điểm làm việc': ['- Hà Nội: Tầng 3 TTTM, tòa nhà CTM Complex, số 139 Cầu Giấy, Phường Quan Hoa, Cầu Giấy'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '1 năm', 'Số lượng tuyển': '1 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 22:54:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/system-engineer-system-admin/1312755.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/full-stack-php-thu-nhap-tu-25-000-000-35-000-000-trieu-thang/1309834.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 22:54:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/system-engineer-system-admin/1312755.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['System Engineer', '/ System Admin'], 'company_name': 'CÔNG TY TNHH PHÁT TRIỂN VĂN HÓA CÔNG NGHỆ INTERNET ATG', 'address': ['Tầng 6, Victory Tower, số 12 đường Tân Trào, Phường Tân Phú, Quận 7, Hồ Chí Minh'], 'salary': ['18 - 35 triệu'], 'exp': 'Kinh nghiệm', 'remaining': '23/05/2024', 'Mô tả công việc': ['- Responsible for the daily operation and management of servers and databases to ensure high availability;', '- Responsible for the deployment and management of network, mail, firewall, system security, virus protection programs;', '- Responsible for product version release, system deployment, daily troubleshooting, as well as system monitoring, disaster recovery, automated operation and maintenance program development and implementation;', '- Responsible for online application monitoring, maintenance and optimization, to ensure the normal operation of various business systems;', '- Responsible for contingency management, problem tracking and management, provide operation and maintenance reports;', '- Take the initiative to find out the problems and hidden dangers of the production environment, and reduce the maintenance cost of manual operation by developing or advancing automated operation and maintenance tools.'], 'Yêu cầu ứng viên': ['- Computer or related majors, bachelor degree or above, more than 3 years related IT operation and maintenance work experience;', '- Familiar with the management and maintenance of network equipment such as switches, firewalls, routers, etc. as well as the maintenance and configuration of computers and external devices;', '- Proficient in Linux / Windows operating system management, familiar with KVM, VMware and other virtualization technologies;', '- Proficient in the use of Shell, Perl, Python (one or more) languages, skilled in scripting / tool development, a deeper understanding or experience in automated operations and maintenance is preferred;', '- Skilled in MySQL, such as backup, upgrade, recovery and monitoring to ensure data security;', '- Proficiency in Apache, Tomcat, MySQL, Redis, Zabbix, elk, jenkins and other applications to build, configure, optimize;', '- With strong fault analysis and troubleshooting ability, good at learning on the job, can withstand work pressure;', '- Have good communication, execution ability and strong sense of responsibility.'], 'Quyền lợi': ['Trial period: 1-2 months', 'Salary: 18-35 million VND/month (determined by negotiation according to ability)'], 'Địa điểm làm việc': ['- Hồ Chí Minh: Tầng 6, Victory Tower, số 12 đường Tân Trào, Phường Tân Phú, Quận 7'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 09:00 đến 18:00)', 'Nghỉ trưa 1,5 tiếng', 'Thứ bảy làm việc cách tuần'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '3 năm', 'Số lượng tuyển': '2 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 22:54:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/it-support-shopify-fulltime-chia-ca-linh-hoat-co-html-css-tieng-anh-tot-thu-nhap-8-12m-thuong/1310314.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/system-engineer-system-admin/1312755.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 22:54:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/it-support-shopify-fulltime-chia-ca-linh-hoat-co-html-css-tieng-anh-tot-thu-nhap-8-12m-thuong/1310314.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['IT Support', 'Shopify Fulltime (Chia Ca Linh Hoạt, Có HTML/CSS, Tiếng Anh Tốt, Thu Nhập 8-12M+Thưởng)'], 'company_name': 'CÔNG TY CỔ PHẦN DỊCH VỤ VÀ PHÁT TRIỂN CÔNG NGHỆ BEAE VIỆT NAM', 'address': ['Số 114 Trần Vỹ, Phường Mai Dịch, Quận Cầu Giấy, Thành phố Hà Nội, Việt Nam'], 'salary': ['8 - 12 triệu'], 'exp': 'Kinh nghiệm', 'remaining': '22/05/2024', 'Mô tả công việc': ['- Sử dụng live chat để trả lời các câu hỏi của khách hàng liên quan tới sản phẩm bằng tiếng Anh.', '- Tiếp nhận và xử lý các vấn đề kĩ thuật liên quan tới HTML/CSS.', '- Số ca làm việc sẽ linh động và được sự phân công từ trưởng nhóm. Chia ca phù hợp để đảm bảo về mặt sức khoẻ.', '- Xin được rating sau mỗi cuộc hội thoại với khách hàng khi đã giải quyết được các vấn đề cho khách và khách hàng hài lòng đó là thời điểm phù hợp để xin đánh giá.', '- Sử dụng email hoặc các kênh social để liên lạc và kết nối với khách hàng nếu cần thiết.', '- Học, sử dụng thành thạo và hiểu rõ về sản phẩm để có thể giải quyết các vấn đề khi khách gặp phải.', '- Được đào tạo để hiểu về sản phẩm tại văn phòng công ty giờ hành chính (dự kiến kéo dài 2 tuần - 1 tháng)'], 'Yêu cầu ứng viên': ['- Có kỹ năng giao tiếp tiếng Anh tốt với khách hàng qua chat (chủ yếu khách US - UK)', '- Đã học và có nền tảng về công nghệ thông tin, có hiểu biết về HTML, CSS là một lợi thế.', '- Hiểu về e-Commerce (ưu tiên đã chăm sóc các sản phẩm trên nền tảng Shopify hoặc nền tảng tương tự), Đã từng support các app hoặc plugin chuyên về e-Commerce là một lợi thế và đặc biệt là app page builder.', '- Thái độ làm việc nghiêm túc và nhiệt tình hết mình mang lại giá trị giúp khách hàng thành công.'], 'Quyền lợi': ['- Lương cơ bản từ 8-12M + thưởng', '- Có cơ hội thăng tiến lên Leader', '- Được chia cổ phần % dự án nếu có đóng góp lớn cho sản phẩm.', '- Có lương cứng cố định + thưởng vượt hiệu suất làm việc lên tới 80% ( thưởng tháng, thưởng quý)', '- Được đóng bảo hiểm theo quy định, review lương 6 tháng/lần, du lịch, sinh nhật nhân sự hàng tháng,...', '- Được sử dụng miễn phí các tiện ích của văn phòng: máy pha cà phê, tủ lạnh, lò vi sóng, trà, hoa quả, snack,...', '- Thưởng lương tháng thứ 13 và thưởng hiệu quả công việc năm, các chế độ và thưởng các ngày lễ tết theo quy định.', '- Được làm việc trực tiếp với khách hàng cao cấp nước ngoài, có cơ hội trau dồi kỹ năng và trình độ.', '- Được khuyến khích đưa ra các ý tưởng và đề xuất cải thiện sản phẩm và cùng thảo luận với đội ngũ phát triển sản phẩm.', '- Môi trường trẻ và năng động, lộ trình thăng tiến rõ ràng.'], 'Địa điểm làm việc': ['- Hà Nội: Tầng 8, 114 Trần Vỹ, Mai Dịch, Cầu Giấy'], 'Thời gian làm việc': ['Thời gian làm việc sẽ được chia theo ca (4 tiếng/ca) và mỗi ngày không quá 2 ca:', 'Ca A remote (từ 3h30-7h30)', 'Ca B tại công ty (8h-12h)', 'Ca C tại công ty (từ 13h15’- 17h15’)', 'Ca D remote (từ 18h-22h)', 'Ca E remote (từ 23h-3h)'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '1 năm', 'Số lượng tuyển': '5 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# ...
# 2024-04-23 23:22:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/tts-front-end-developer/1227075.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['TTS Front-End', 'Developer'], 'company_name': 'CÔNG TY CỔ PHẦN OKHUB VIỆT NAM', 'address': ['HPC Landmark 105, Hà Đông, Hà Nội'], 'salary': ['Trên 1 triệu'], 'exp': 'Kinh nghiệm', 'remaining': '23/05/2024', 'Mô tả công việc': ['Số lượng : 2 bạn', 'Phát triển Front-end bằng Reactjs, Nextjs', 'Phát triển các website Wordpress Front-end theo yêu cầu của quản lý'], 'Yêu cầu ứng viên': ['Đã tốt nghiệp hoặc là sinh viên năm cuối chuyên ngành Công nghệ thông tin, Toán tin, Khoa học máy tính, Kỹ thuật phần mềm, Điện tử viễn thông... hoặc các chuyên ngành có liên quan (không bắt buộc)', 'Có thời gian fulltime hoặc 90% khi bắt đầu đi làm.', 'Có tìm hiểu về wordpress', 'Thành thạo HTML5/CSS3.', 'Có kiển thức về Javascript, Reactjs, Nextjs', 'Tư duy lập trình tốt, có thể mở rộng, tùy biến chức năng bằng code PHP (không bắt buộc).', 'Có khả năng phân tích tính năng của các website.', 'Năng động, sáng tạo, ham học hỏi, chủ động tìm tòi phát triển bản thân.'], 'Quyền lợi': ['Trợ cấp 1.000.000 VNĐ trong tháng đầu tiên thực tập. Từ tháng thứ 2 trở đi thu nhập theo năng lực và số dự án tham gia', 'Khi đủ năng lực sẽ được xét lên nhân viên chính thức (khoảng 6 tháng)', 'Hưởng chế độ BHXH theo luật lao động.', 'Làm việc trong môi trường năng động, trẻ trung và thân thiện.', 'Nghỉ lễ theo quy định của Luật lao động hiện hành và theo quy định của Công ty.', 'Được học hỏi và hướng dẫn từ những người có kinh nghiệm.'], 'Địa điểm làm việc': ['- Hà Nội: đường dọc bún 2, phường Văn Khê, quận Hà Đông, Hà Đông'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 08:30 đến 18:00)', 'Từ t2 đến t6 và 2 t7 cách tuần trong tháng'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': 'Không yêu cầu kinh nghiệm', 'Số lượng tuyển': '2 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 23:22:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/lap-trinh-vien-net/1312352.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/tts-front-end-developer/1227075.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 23:22:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/lap-trinh-vien-net/1312352.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Lập Trình Viên .Net'], 'company_name': 'Công ty TNHH phần mềm 2NF', 'address': ['tòa nhà 3a, ngõ 82 Duy Tân, Cầu Giấy, Hà Nội'], 'salary': ['20 - 35 triệu'], 'exp': '4 năm', 'remaining': '23/05/2024', 'Mô tả công việc': ['• Đọc tài liệu và phân tích yêu cầu từ khách hàng: specs, design', '• Viết tài liệu chi tiết về dự án', '• Tư vấn khách hàng', '• Thiết kế hệ thống', '• Coding', '• Thực hiện unit test theo nhu cầu dự án', '• Báo cáo hàng ngày với teamleader hoặc PM dự án', '• Hỗ trợ team cùng phát triển', '• Cập nhật tiến độ công việc hàng ngày vào tool quản lý dự án', '• Thực hiện đúng quy trình phát triển phần mềm'], 'Yêu cầu ứng viên': ['• Tốt nghiệp Đại học/Cao Đẳng chuyên ngành CNTT.', '• Yêu cầu trình độ đọc hiểu tiếng Anh.', '• Có trên 4 năm làm việc ở vị trí tương đương', '• Biết xây dựng DB và project base tư vấn perfomance', '• Có khả năng quản lý team, quản lý công nghệ', '• Có khả năng đọc hiểu các tài liệu specs, design', '• Có khả năng tạo các tài liệu mô tả yêu cầu', '• Có khả năng giao tiếp, làm việc nhóm, khả năng giao tiếp với khách hàng.', '• Có kiến thức về 3 trong các cơ sở dữ liệu SQL như Mysql, SQL Server, Postgresql, Oracle', '• Ưu tiên có kiến thức về Nosql như MongoDB', '• Ưu tiên đã từng làm việc với memcached hoặc redis', '• Hiểu về js. Có thể sử dụng các open source hoặc framework sau: angular,...', '• Có hiểu biết về scss và sass', '• Biết phân tích thiết kế hệ thống. Hiểu về các design pattern như WPF, MVC, MVVM', '• Hiểu biết về webform ASP.NET (C#, VB.NET) và ASP.NET MVC', '• Hiểu biết về Webservice, WCF, WebAPI, SOAP', '• Hiểu biết về các phương thức Authenticate như Oauth2.0, Basic Authentication, Session Authentication...', '• Có hiểu biết về winform, Window Universal', '• Sử dụng thành thạo các công cụ quản lý source code như SVN, git, gitlab', '• Đã từng làm việc với các API như facebookAPI, googleAPI', '• Đã từng làm việc với môi trường amazon như EC2, Elastic Search, S3.'], 'Quyền lợi': ['• Lương upto 35 tr', '• Xét tăng lương 1 năm 2 lần (định kỳ vào tháng 06 và tháng 12)', '• Đóng BHXH, BHYT, BHTN theo quy định nhà nước khi ký HĐLĐ chính thức với Công ty', '• Được tham gia các khóa học tiếng Anh, tiếng Nhật tại Công ty (công ty hỗ trợ).', '• Được khám sức khỏe định kỳ 1 năm 1 lần vào tháng 5', '• Hưởng đầy đủ chính sách phúc lợi của Công ty: thưởng các dịp Lễ, Tết, lương tháng 13, thưởng kinh doanh, du lịch, teambuilding,...', '• Môi trường chuyên nghiệp, năng động, trẻ trung, cởi mở'], 'Địa điểm làm việc': ['- Hà Nội: tòa nhà 3a, ngõ 82 Duy Tân, Cầu Giấy'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 08:30 đến 17:30)'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '4 năm', 'Số lượng tuyển': '1 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 23:22:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-designer/692594.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/lap-trinh-vien-net/1312352.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 23:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-designer/692594.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Nhân Viên', 'Designer'], 'company_name': 'Công ty cổ phần tư vấn đầu tư xây dựng và thương mại Thanh Giang - THANH GIANG CONINCON., JSC', 'address': ['Lô N7A, khu tái định cư X2A, Yên Sở, Hoàng Mai, Hà Nội'], 'salary': ['9 - 12 triệu'], 'exp': 'Kinh nghiệm', 'remaining': '30/06/2024', 'Mô tả công việc': ['- Xây dựng kế hoạch sản xuất video theo yêu cầu của bộ phận.', '- Sản xuất video, quay phim, dựng phim, cắt ghép nội dung, tạo hiệu ứng cho video...', '- Thiết kế banner, ấn phẩm...', '- Chịu trách nhiệm quản lý và phát triển kênh Youtube và Fanpage của công ty.', '- Đề xuất ý tưởng , nội dung,thực hiện sản xuất các clip quảng bá hình ảnh ,hoạt động và dịch vụ của công ty.', '- Tham gia tham gia cuộc họp liên quan và một số hoạt động chung của phòng/công ty như quy định', '- Thực hiện các công việc khác theo sự sắp xếp của lãnh đạo công ty.'], 'Yêu cầu ứng viên': ['Ứng viên có kinh nghiệm làm Desiger', 'Nhanh nhẹn, chăm chỉ, nhiệt tình, các nghiệp vụ khác được đào tạo', 'Ưu tiên ứng viên có hiểu biết về hệ thống mạng xã hội.'], 'Quyền lợi': ['Thu nhập cạnh tranh, thoả thuận theo năng lực, gồm: Lương cứng thỏa thuận từ (9-12 triệu/ tháng) + thưởng xuất cảnh + phụ cấp khác, được làm trong môi trường làm việc năng động, có cơ hội thăng tiến.', 'Thưởng tết theo kết quả kinh doanh tháng / cuối năm, thưởng các ngày lễ tết trong năm. Được hưởng đầy đủ các chế độ BHXH theo quy định.', 'Được hưởng các chế độ phúc lợi: hiếu hỉ, sinh nhật CBNV, nghỉ mát, du xuân,...', 'Được tham gia các khóa đào tạo nội bộ và bên ngoài nhằm trang bị, bồi dưỡng kiến thức, kỹ năng mềm phục vụ cho công việc.', 'Môi trường làm việc năng động, chuyên nghiệp, thân thiện', 'Thưởng theo mức độ hoàn thành công việc'], 'Địa điểm làm việc': ['- Hà Nội: Hưng Thịnh, Khu tái định cư X2A, Phường Yên Sở, Hoàng Mai'], 'Thời gian làm việc': ['- Thời gian làm việc từ 8h sáng -> 17h chiều từ T2->T6 và 2 T7/ 1 tháng'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': 'Dưới 1 năm', 'Số lượng tuyển': '2 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Nam'}
# 2024-04-23 23:23:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/thuc-tap-sinh-van-hanh-he-thong-system-engineer/1312274.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/nhan-vien-designer/692594.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 23:23:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/thuc-tap-sinh-van-hanh-he-thong-system-engineer/1312274.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['Thực Tập Sinh Vận Hành Hệ Thống -', 'System Engineer'], 'company_name': 'NetNam Corp', 'address': ['Khu thử nghiệm công nghệ, số 18 Hoàng Quốc Việt, P. Nghĩa Đô, Q. Cầu Giấy, TP. Hà Nội'], 'salary': ['Thoả thuận'], 'exp': 'Kinh nghiệm', 'remaining': '25/05/2024', 'Mô tả công việc': ['Thực tập sinh tại NetNam sẽ được hướng dẫn, huấn luyện bởi các kỹ sư có kinh nghiệm và được thực hành các mảng công việc tùy theo đăng ký chuyên môn sau:', '• IPv6', '• Cloud Computing', '• An toàn - an ninh mạng', '• Các hệ thống, giải pháp mạng dựa trên Phần mềm nguồn mở', '• Giải pháp mạng không dây Wifi chuyên biệt', '• Nghiên cứu/Triển khai các dự án Giải pháp Công nghệ cho các khách sạn cao cấp, cơ quan bộ ngành, (tác nghiệp trên các thiết bị router, switch, firewall, gateway trên quy mô lớn)', '• Các hệ thống, giải pháp mạng dựa trên Phần mềm nguồn mở', '• Giải pháp mạng không dây Wifi chuyên biệt'], 'Yêu cầu ứng viên': ['• Sinh viên các trường đại học khối Công nghệ thông tin, Điện tử viễn thông, Toán tin ứng dụng và các chuyên ngành khác có liên quan năm thứ ba trở đi.', '• Hiểu biết nhất định về phần mềm CNTT...', '• Tư duy logic tốt, học lực khá,Tiếng Anh giao tiếp tốt là một ưu tiên', '• Theo học chuyên ngành Điện tử viễn thông, Công nghệ thông tin', '• Điểm trung bình trung học tập > 7.5/10', '• Đã học xong hoặc có chứng chỉ CCNA', '• Tiếng Anh giao tiếp căn bản; đọc hiểu tài liệu chuyên ngành tốt', '• Có kiến thức về Network; Thiết bị (DSLAM, Router, swich..)'], 'Quyền lợi': ['Có cơ hội được nhận thù lao theo hiệu quả công việc và được ưu tiên nhận vào làm việc tại công ty sau tốt nghiệp nếu đáp ứng đủ các tiêu chuẩn tuyển dụng của Công ty', 'Môi trường làm việc: thân thiện, năng động, khuyến khích sự sáng tạo và thay đổi.', 'CLB thể thao như Bóng đá, Yoga, chạy ... luôn được công ty hỗ trợ và hoạt động hết công suất.', 'Cơ hội huấn luyện:', 'o Được các chuyên gia về công nghệ có kinh nghiệm hướng dẫn kèm cặp trong quá trình làm việc', 'o Đươc đào tạo về sản phẩm/dịch vụ mở rộng phạm vi kiến thức/công nghệ mới. Công ty tài trợ chi phí các khóa CEH, CCNP, CCIE, JNCIE, ITIL, LPI... nếu nhân sự cần và mong muốn nâng cao chuyên môn.', 'o Được tham gia các khóa học nước ngoài của khu vực Châu Á Thái Bình Dương về CNTT và Internet (Apricot/APNIC ....)'], 'Địa điểm làm việc': ['- Hà Nội: Nhà 2A, Viện Hàn lâm KH&CN VN, 18 Hoàng Quốc Việt, Cầu Giấy, Hà Nội, Cầu Giấy'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 08:00 đến 17:30)'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Thực tập sinh', 'Kinh nghiệm': 'Không yêu cầu kinh nghiệm', 'Số lượng tuyển': '1 người', 'Hình thức làm việc': 'Thực tập', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 23:23:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/it-project-manager-pm-it/1311127.html?ta_source=ITJobs_LinkDetail> (referer: https://www.topcv.vn/viec-lam/thuc-tap-sinh-van-hanh-he-thong-system-engineer/1312274.html?ta_source=ITJobs_LinkDetail)
# 2024-04-23 23:23:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/it-project-manager-pm-it/1311127.html?ta_source=ITJobs_LinkDetail>
#
# {'job_name': ['IT', 'Project Manager', '(PM IT)'], 'company_name': 'INTERNATIONAL TOURISM HUMAN RESOURCE SERVICES CO., LTD.', 'address': ['Số 214 Trần Quang Khải, Phường Tràng Tiền, Quận Hoàn Kiếm, Thành phố Hà Nội, Việt Nam'], 'salary': ['15 - 25 triệu'], 'exp': 'Hà Nội', 'remaining': '30/06/2024', 'Mô tả công việc': ['• Quản lý các dự án CNTT được giao; Lập kế hoạch chi tiết và thực hiện các dự án CNTT theo sự phân công từ Giám đốc CNTT.', '• Ước tính và phân bổ nguồn lực cần thiết cho dự án', '• Đánh giá thường xuyên tình trạng dự án để báo cáo kịp thời cho Ban Giám đốc, khách hàng và các bên liên quan khác.', '• Quản lý công việc hàng ngày của dự án. Chịu trách nhiệm đánh giá và đảm bảo rằng chất lượng tổng thể của việc giao dự án trước khi bàn giao cho khách hàng.', '• Đảm bảo sự tham gia của các bên liên quan của dự án và sự hợp tác giữa các bên liên quan.', '• Chủ động đánh giá rủi ro và các vấn đề của dự án, thiết lập kế hoạch giảm thiểu / kế hoạch giải quyết và liên lạc kịp thời và leo thang tới các bên liên quan.', '• Cập nhật về ngân sách dự án / tiến độ / phạm vi / tài nguyên.', '• Cùng đánh giá các giải pháp CNTT được chọn (nếu cần)', '• Phối hợp với các PM khác nếu có sự phụ thuộc với các dự án khác', '• Có khả năng nghiên cứu các công nghệ mới / xu hướng công nghiệp mới nhất; Giao tiếp, chia sẻ và đào tạo cho các thành viên để nâng cao tính chuyên nghiệp và hiệu quả làm việc.', '• Góp phần cải thiện quy trình quản lý dự án CNTT', '• Thực hiện một số công việc khác khi có yêu cầu của cấp trên khi được phân công.'], 'Yêu cầu ứng viên': ['- Tốt nghiệp Đại học các ngành CNTT/Điện tử viễn thông hoặc tương đương.', '- Có kinh nghiệm làm trưởng nhóm hoặc PM các dự án CNTT.', '- Có khả năng bao quát công việc, xử lý tình huống linh hoạt, khả năng làm việc độc lập, chủ động', '- Kỹ năng giao tiếp, đàm phán, lập kế hoạch và giải quyết vấn đề', '- Trung thực, cẩn trọng, ngăn nắp, tinh thần trách nhiệm cao', '- Ưu tiên có kinh nghiệm làm Tư vấn và triển khai dự án CNTT', '- Ưu tiên có Chứng chỉ Quản lý dự án', '- Ưu tiên có hiểu biết về các hệ thống dịch vụ công là 1 lợi thế'], 'Quyền lợi': ['- Mức lương : Lương cứng từ 15.000.000đ - 25.000.000đ + thưởng dự án (tùy năng lực)', '- Được đánh giá, xét thưởng định kỳ hàng năm.', '- Được trang bị đầy đủ thiết bị làm việc', '- Hưởng phúc lợi ngày sinh nhât, các ngày lễ: 2/9, 30/04, 1/5, 1/6, ..', '- Du lịch, nghỉ mát định kỳ hàng năm', '- Thời gian làm việc: từ thứ 2- thứ 6 (nghỉ Thứ 7, CN)'], 'Địa điểm làm việc': ['- Hà Nội: Số 214 Trần Quang Khải, Phường Tràng Tiền, Hoàn Kiếm'], 'Thời gian làm việc': ['Thứ 2 - Thứ 6 (từ 07:00 đến 16:00)'], 'Cách thức ứng tuyển': ['Ứng viên nộp hồ sơ trực tuyến bằng cách bấm', 'Ứng tuyển', 'ngay dưới đây.'], 'Cấp bậc': 'Nhân viên', 'Kinh nghiệm': '1 năm', 'Số lượng tuyển': '1 người', 'Hình thức làm việc': 'Toàn thời gian', 'Giới tính': 'Không yêu cầu'}
# 2024-04-23 23:23:06 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-04-23 23:23:06 [scrapy.extensions.feedexport] INFO: Stored json feed (82 items) in: json/out.json
# 2024-04-23 23:23:06 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 98122,
#  'downloader/request_count': 83,
#  'downloader/request_method_count/GET': 83,
#  'downloader/response_bytes': 8126399,
#  'downloader/response_count': 83,
#  'downloader/response_status_count/200': 83,
#  'elapsed_time_seconds': 1736.032433,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 4, 23, 16, 23, 6, 228170, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 35907585,
#  'httpcompression/response_count': 83,
#  'item_scraped_count': 82,
#  'log_count/DEBUG': 169,
#  'log_count/INFO': 25,
#  'request_depth_max': 81,
#  'response_received_count': 83,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 82,
#  'scheduler/dequeued/memory': 82,
#  'scheduler/enqueued': 82,
#  'scheduler/enqueued/memory': 82,
#  'start_time': datetime.datetime(2024, 4, 23, 15, 54, 10, 195737, tzinfo=datetime.timezone.utc)}
# 2024-04-23 23:23:06 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !python json/save_mongo.py
# Out:
# Connected to MongoDB
# Success
