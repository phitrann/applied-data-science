# %%
import re
from typing import List, Tuple
import pdfplumber

class ResumeParser:
    def __init__(self):
        self.text_items = []
        self.lines = []
        self.sections = []

    def read_pdf(self, pdf_file):
        """
        Step 1. Read the text items from a PDF file
        """
        with pdfplumber.open(pdf_file) as pdf:
            page = pdf.pages[0]
            # self.text_items = page.extract_text(x_tolerance=1, y_tolerance=1)
            self.text_items = page.extract_words(extra_attrs=['fontname'])

    def group_text_items_into_lines(self):
        """
        Step 2. Group text items into lines
        """
        line = []
        for item in self.text_items:
            if line and self.distance(line[-1], item) > self.avg_char_width * 1.5:
                self.lines.append(line)
                line = []
            line.append(item)
        if line:
            self.lines.append(line)

    def distance(self, item1, item2):
        return abs(item2['x0'] - item1['x1'])
    
    def is_bold(self, item):
        return "Bold" in item['fontname']

    @property
    def avg_char_width(self):
        # total_width = sum(item['x1'] - item['x0'] for item in self.text_items if not item['upright'])
        # total_chars = sum(len(item['text']) for item in self.text_items if not item['upright'])
        total_width = sum(item['x1'] - item['x0'] for item in self.text_items if self.is_bold(item))
        total_chars = sum(len(item['text']) for item in self.text_items if self.is_bold(item))
        return total_width / total_chars if total_chars else 0

    def group_lines_into_sections(self):
        """
        Step 3. Group lines into sections
        """
        current_section = []
        for line in self.lines:
            if self.is_section_title(line[0]):
                if current_section:
                    self.sections.append(current_section)
                current_section = [line]
            else:
                current_section.append(line)
        if current_section:
            self.sections.append(current_section)
        

    def is_section_title(self, text_item):
        if self.is_bold(text_item) and text_item['text'].isupper():
            return True
        return any(keyword in text_item['text'].lower() for keyword in self.section_titles)

    section_titles = [
        'about', 'profile', 'objective', 'education', 'certifications', 'experience', 'skills',
        'projects', 'honors', 'awards', 'involvement', 'volunteer'
    ]

    def extract_resume_from_sections(self):
        """
        Step 4. Extract resume from sections
        """
        resume = {}
        
        resume.update(self.extract_profile(self.sections[0]))
        
        for section in self.sections:
            section_title = section[0][0]['text'].lower()
            if section_title == 'profile':
                resume.update(self.extract_profile(section))
            elif section_title == 'education':
                resume['education'] = self.extract_education(section)
            elif section_title == 'experience':
                resume['experience'] = self.extract_experience(section)
            elif section_title == 'skills':
                resume['skills'] = self.extract_skills(section)
            # Add more section extractors as needed

        return resume
    
    def merge_line(self, line: List[Dict[str, Any]]) -> Dict[str, Any]:
        """
        Merge words in a line into a single text item.
        """
        merged_text = ' '.join(item['text'] for item in line)
        return {
            'text': merged_text,
            'fontname': line[0]['fontname'],  # Assuming the same font for simplicity
            'x0': line[0]['x0'],
            'x1': line[-1]['x1'],
            'top': line[0]['top'],
            'bottom': line[0]['bottom'],
            'upright': line[0]['upright']
        }
        
    def extract_profile(self, section):
        profile = {}
        profile_section = []
        for line in section:
            profile_section.append(self.merge_line(line))
        
            
        for item in profile_section:
            score, attribute = max((self.score_feature(item, attr), attr) for attr in self.profile_attrs)
            if score > 0:
                profile[attribute] = item['text']
        return profile

    profile_attrs = ['name', 'email', 'phone', 'location', 'url'] #, 'summary']

    def score_feature(self, text_item, attr):
        score = 0
        for feature, weight in self.profile_features[attr]:
            if callable(feature):
                if feature(text_item):
                    score += weight
            else:
                if feature.match(text_item['text']):
                    score += weight
        return score

    profile_features = {
        'name': [
            (re.compile(r'^[a-zA-Z\s\.]+$'), 3),
            (lambda item: 'Bold' in item['fontname'], 2),
            (lambda item: item['text'].isupper(), 2),
            (lambda item: '@' in item['text'], -4),
            (lambda item: any(char.isdigit() for char in item['text']), -4),
            (lambda item: ',' in item['text'], -4),
            (lambda item: '/' in item['text'], -4),
        ],
        'email': [
            (re.compile(r'\S+@\S+\.\S+'), 10),
        ],
        'phone': [
            (re.compile(r'\(?\d{3}\)?[\s-]?\d{3}[\s-]?\d{4}'), 10),
        ],
        'location': [
            (re.compile(r'[A-Z][a-z]+, [A-Z]{2}'), 10),
        ],
        'url': [
            (re.compile(r'https?://\S+'), 10),
        ],
        
        # Add more feature sets as needed
    }

    def extract_education(self, section):
        education = []
        subsections = self.split_into_subsections(section[1:])
        for subsection in subsections:
            degree = self.extract_degree(subsection)
            if degree:
                education.append(degree)
        return education

    def extract_degree(self, subsection):
        degree = {}
        for line in subsection:
            if self.is_school(line[0]):
                degree['school'] = self.merge_line(line)['text']
            elif self.is_degree(line[0]):
                degree['degree'] = self.merge_line(line)['text']
            elif self.is_gpa(line[0]):
                degree['gpa'] = self.merge_line(line)['text']
            elif self.is_date(line[0]):
                degree['date'] = self.merge_line(line)['text']
            else:
                degree['description'] = self.merge_line(line)['text']
        return degree

    def is_school(self, text_item):
        return any(keyword in text_item['text'].lower() for keyword in ['university', 'college', 'school'])

    def is_degree(self, text_item):
        return any(keyword in text_item['text'].lower() for keyword in ['bachelor', 'master', 'associate'])

    def is_gpa(self, text_item):
        return re.match(r'[0-9]\.\d{1,2}', text_item['text']) is not None

    def is_date(self, text_item):
        return any(keyword in text_item['text'].lower() for keyword in ['year', 'month', 'present'])

    def split_into_subsections(self, lines):
        subsections = []
        current_subsection = []
        for i in range(len(lines)):
            if i == len(lines) - 1 or self.is_new_subsection(lines[i], lines[i + 1]):
                current_subsection.append(lines[i])
                subsections.append(current_subsection)
                current_subsection = []
            else:
                current_subsection.append(lines[i])
        return subsections

    def is_new_subsection(self, line1, line2):
        return any(self.is_bold(item) for item in line2) and self.line_gap(line1, line2) > self.avg_line_gap * 1.4

    @property
    def avg_line_gap(self):
        gaps = []
        for i in range(len(self.lines) - 1):
            line1, line2 = self.lines[i], self.lines[i + 1]
            gap = line2[0]['bottom'] - line1[-1]['top']
            gaps.append(gap)
        return sum(gaps) / len(gaps) if gaps else 0

    def line_gap(self, line1, line2):
        return line2[0]['bottom'] - line1[-1]['top']

    def extract_experience(self, section):
        experiences = []
        subsections = self.split_into_subsections(section[1:])
        for subsection in subsections:
            experience = self.extract_experience_subsection(subsection)
            if experience:
                experiences.append(experience)
        return experiences

    def extract_experience_subsection(self, subsection):
        experience = {}
        for line in subsection:
            if self.is_company(line[0]):
                experience['company'] = line[0]['text']
            elif self.is_job_title(line[0]):
                experience['job_title'] = line[0]['text']
            elif self.is_date(line[0]):
                experience['date'] = line[0]['text']
            else:
                if 'description' not in experience:
                    experience['description'] = []
                experience['description'].append(line[0]['text'])
        return experience

    def is_company(self, text_item):
        return self.is_bold(text_item) or not self.is_job_title(text_item)

    def is_job_title(self, text_item):
        return any(keyword in text_item['text'].lower() for keyword in ['analyst', 'engineer', 'intern', 'manager', 'developer'])

    def extract_skills(self, section):
        skills = []
        for line in section[1:]:
            for item in line:
                if item['upright']:
                    skills.append(item['text'])
        return skills

# Usage example
parser = ResumeParser()
parser.read_pdf('../data/cv/CV_SonBao_DS.pdf')
parser.group_text_items_into_lines()
parser.group_lines_into_sections()
resume = parser.extract_resume_from_sections()
from pprint import pprint
pprint(resume)
# Out:
# {'education': [{'degree': 'Bachelor Degree in Data Science (2020-2024)',
#                 'description': 'Cumulative GPA: 7.6/10',
#                 'school': 'University of Economics, Ho Chi Minh City - Viet '
#                           'Nam'}],
#  'name': 'PHAN TRAN SON BAO',
#  'phone': '0938009294 | sonbao0901@gmail.com | https://github.com/sonbao0901 |',
#  'skills': ['Language:',
#             'Python',
#             '(pandas,',
#             'numpy,',
#             'sklearn,',
#             'tensoflow,..),',
#             'SQL.',
#             'Visualization:',
#             'Power',
#             'BI,',
#             'Python',
#             '(matplotlib,',
#             'seaborn).',
#             'Others:',
#             'Excel',
#             '(pivot',
#             'table,',
#             'visualize),',
#             'Word,',
#             'PowerPoint.',
#             'Pursing:',
#             'Statistic,',
#             'Machine',
#             'Learning,',
#             'Deep',
#             'Learning.'],
#  'url': 'https://www.linkedin.com/in/phantransonbao/'}

# %%
parser.split_into_subsections(parser.lines)
# Out:
# [[[{'text': 'PHAN',
#     'x0': 200.47,
#     'x1': 251.14000000000001,
#     'top': 32.545999999999935,
#     'doctop': 32.545999999999935,
#     'bottom': 50.545999999999935,
#     'upright': True,
#     'height': 18.0,
#     'width': 50.670000000000016,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'TRAN',
#     'x0': 256.144,
#     'x1': 306.43199999999996,
#     'top': 32.545999999999935,
#     'doctop': 32.545999999999935,
#     'bottom': 50.545999999999935,
#     'upright': True,
#     'height': 18.0,
#     'width': 50.287999999999954,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'SON',
#     'x0': 311.364,
#     'x1': 350.33599999999996,
#     'top': 32.545999999999935,
#     'doctop': 32.545999999999935,
#     'bottom': 50.545999999999935,
#     'upright': True,
#     'height': 18.0,
#     'width': 38.97199999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'BAO',
#     'x0': 355.34,
#     'x1': 395.264,
#     'top': 32.545999999999935,
#     'doctop': 32.545999999999935,
#     'bottom': 50.545999999999935,
#     'upright': True,
#     'height': 18.0,
#     'width': 39.924000000000035,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': '0938009294',
#     'x0': 119.33,
#     'x1': 180.57992,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 61.24991999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '|',
#     'x0': 183.78152,
#     'x1': 186.65192,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 2.8703999999999894,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'sonbao0901@gmail.com',
#     'x0': 189.67,
#     'x1': 311.51847999999995,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 121.84847999999997,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '|',
#     'x0': 314.76,
#     'x1': 317.6304,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 2.870400000000018,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'https://github.com/sonbao0901',
#     'x0': 320.52,
#     'x1': 470.69712,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 150.17712,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '|',
#     'x0': 474.19,
#     'x1': 477.0604,
#     'top': 56.065279999999916,
#     'doctop': 56.065279999999916,
#     'bottom': 67.10527999999988,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 2.870400000000018,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'https://www.linkedin.com/in/phantransonbao/',
#     'x0': 188.95,
#     'x1': 407.02312,
#     'top': 68.78527999999994,
#     'doctop': 68.78527999999994,
#     'bottom': 79.8252799999999,
#     'upright': True,
#     'height': 11.039999999999964,
#     'width': 218.07312000000002,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}]],
#  [[{'text': 'About',
#     'x0': 24.0,
#     'x1': 58.452000000000005,
#     'top': 97.54399999999998,
#     'doctop': 97.54399999999998,
#     'bottom': 109.54399999999998,
#     'upright': True,
#     'height': 12.0,
#     'width': 34.452000000000005,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'I',
#     'x0': 24.0,
#     'x1': 26.53536,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 2.5353600000000007,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'am',
#     'x0': 29.25312,
#     'x1': 41.6472,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 12.394079999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'a',
#     'x0': 44.118719999999996,
#     'x1': 49.18944,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 5.0707200000000014,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'senior',
#     'x0': 51.56063999999999,
#     'x1': 76.19375999999998,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 24.63311999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'student',
#     'x0': 78.66528,
#     'x1': 108.07727999999996,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 29.411999999999964,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'at',
#     'x0': 110.56703999999996,
#     'x1': 118.14575999999995,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 7.57871999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'the',
#     'x0': 120.63551999999996,
#     'x1': 133.37615999999994,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 12.740639999999985,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'University',
#     'x0': 135.72911999999994,
#     'x1': 175.06367999999992,
#     'top': 116.86784,
#     'doctop': 116.86784,
#     'bottom': 125.98784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width':

#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'I',
#     'x0': 411.53,
#     'x1': 414.06536,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 2.5353600000000256,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'am',
#     'x0': 416.55512,
#     'x1': 428.9492,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 12.39408000000003,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'a',
#     'x0': 431.64871999999997,
#     'x1': 436.71943999999996,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 5.070719999999994,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'dedicated',
#     'x0': 439.13,
#     'x1': 478.01768,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 38.88767999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'person',
#     'x0': 480.61688,
#     'x1': 508.24136,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 27.624480000000005,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'and',
#     'x0': 510.36632,
#     'x1': 525.52376,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 15.157440000000065,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'a',
#     'x0': 528.1229599999999,
#     'x1': 533.19368,
#     'top': 128.89783999999997,
#     'doctop': 128.89783999999997,
#     'bottom': 138.01783999999998,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 5.070720000000051,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'collaborative',
#     'x0': 24.0,
#     'x1': 74.89872,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 50.89872,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'teammate.',
#     'x0': 77.02367999999998,
#     'x1': 119.58671999999994,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 42.56303999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'I',
#     'x0': 122.21,
#     'x1': 124.74535999999999,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 2.535359999999997,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'find',
#     'x0': 127.23512,
#     'x1': 141.90007999999997,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 14.66495999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'working',
#     'x0': 144.25304,
#     'x1': 175.2428,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 30.98975999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'with',
#     'x0': 177.84199999999998,
#     'x1': 193.70168,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 15.859680000000026,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'data',
#     'x0': 196.30088,
#     'x1': 213.83863999999997,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 17.537759999999963,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'and',
#     'x0': 216.19159999999997,
#     'x1': 231.34903999999995,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 15.15743999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'models',
#     'x0': 233.47399999999993,
#     'x1': 262.74008,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 29.266080000000045,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'to',
#     'x0': 265.13863999999995,
#     'x1': 272.60792,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 7.469280000000026,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'be',
#     'x0': 275.20712,
#     'x1': 285.3212,
#     'top': 141.13783999999998,
#     'doctop': 141.13783999999998,
#     'bottom': 150.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width':

#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'your',
#     'x0': 398.57,
#     'x1': 416.01656,
#     'top': 165.13783999999998,
#     'doctop': 165.13783999999998,
#     'bottom': 174.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 17.446560000000034,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'company.',
#     'x0': 418.49,
#     'x1': 457.49624,
#     'top': 165.13783999999998,
#     'doctop': 165.13783999999998,
#     'bottom': 174.25784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 39.00623999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Education',
#     'x0': 24.0,
#     'x1': 82.152,
#     'top': 185.654,
#     'doctop': 185.654,
#     'bottom': 197.654,
#     'upright': True,
#     'height': 12.0,
#     'width': 58.152,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'University',
#     'x0': 27.84,
#     'x1': 71.52479999999998,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 43.68479999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'of',
#     'x0': 73.87776,
#     'x1': 82.43231999999998,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 8.55455999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Economics,',
#     'x0': 85.13183999999998,
#     'x1': 135.41039999999995,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 50.27855999999997,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Ho',
#     'x0': 137.90015999999997,
#     'x1': 149.95679999999996,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 12.056639999999987,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Chi',
#     'x0': 152.52863999999997,
#     'x1': 166.82879999999994,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 14.300159999999977,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Minh',
#     'x0': 169.51,
#     'x1': 190.6684,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 21.1584,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'City',
#     'x0': 193.00312,
#     'x1': 210.06663999999998,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 17.063519999999983,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': '-',
#     'x0': 212.5,
#     'x1': 215.53696,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 3.0369599999999934,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Viet',
#     'x0': 218.26,
#     'x1': 234.48448,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 16.22448,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Nam',
#     'x0': 237.184,
#     'x1': 256.57312,
#     'top': 207.87784,
#     'doctop': 207.87784,
#     'bottom': 216.99784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 19.38912000000002,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'Bachelor',
#     'x0': 27.84,
#     'x1': 63.28943999999999,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 35.449439999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': 'Degree',
#     'x0': 65.98895999999999,
#     'x1': 95.53775999999998,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 29.548799999999986,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': 'in',
#     'x0': 98.208,
#     'x1': 104.95679999999999,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 6.748799999999989,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': 'Data',
#     'x0': 107.556,
#     'x1': 126.78096,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 19.224959999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': 'Science',
#     'x0': 129.13392,
#     'x1': 161.0904,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 31.95648,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': '(2020-2024)',
#     'x0': 163.4616,
#     'x1': 212.63415999999998,
#     'top': 221.79783999999995,
#     'doctop': 221.79783999999995,
#     'bottom': 230.91783999999996,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 49.172559999999976,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'}],
#   [{'text': 'Cumulative',
#     'x0': 27.84,
#     'x1': 72.75599999999999,
#     'top': 236.19783999999993,
#     'doctop': 236.19783999999993,
#     'bottom': 245.31783999999993,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 44.91599999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': 'GPA:',
#     'x0': 75.3552,
#     'x1': 97.07903999999999,
#     'top': 236.19783999999993,
#     'doctop': 236.19783999999993,
#     'bottom': 245.31783999999993,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 21.723839999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'},
#    {'text': '7.6/10',
#     'x0': 99.648,
#     'x1': 124.64263999999999,
#     'top': 236.19783999999993,
#     'doctop': 236.19783999999993,
#     'bottom': 245.31783999999993,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 24.99463999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Oblique'}]],
#  [[{'text': 'Certifications',
#     'x0': 24.0,
#     'x1': 100.67999999999999,
#     'top': 264.874,
#     'doctop': 264.874,
#     'bottom': 276.874,
#     'upright': True,
#     'height': 12.0,
#     'width': 76.67999999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'HackerRank',
#     'x0': 39.384,
#     'x1': 91.25855999999999,
#     'top': 285.15783999999996,
#     'doctop': 285.15783999999996,
#     'bottom': 294.27783999999997,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 51.87455999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'SQL,',
#     'x0': 93.85775999999998,
#     'x1': 114.624,
#     'top': 285.15783999999996,
#     'doctop': 285.15783999999996,
#     'bottom': 294.27783999999997,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 20.76624000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Python',
#     'x0': 117.34176,
#     'x1': 147.85727999999995,
#     'top': 285.15783999999996,
#     'doctop': 285.15783999999996,
#     'bottom': 294.27783999999997,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 30.515519999999952,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': '(Basic)',
#     'x0': 150.19199999999998,
#     'x1': 180.08735999999996,
#     'top': 285.15783999999996,
#     'doctop': 285.15783999999996,
#     'bottom': 294.27783999999997,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 29.895359999999982,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Certificate',
#     'x0': 182.78687999999994,
#     'x1': 226.6996799999999,
#     'top': 285.15783999999996,
#     'doctop': 285.15783999999996,
#     'bottom': 294.27783999999997,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 43.91279999999995,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'HackerRank',
#     'x0': 39.384,
#     'x1': 91.25855999999999,
#     'top': 299.8278399999999,
#     'doctop': 299.8278399999999,
#     'bottom': 308.9478399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 51.87455999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Problem',
#     'x0': 93.85775999999998,
#     'x1': 129.55343999999997,
#     'top': 299.8278399999999,
#     'doctop': 299.8278399999999,
#     'bottom': 308.9478399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 35.69567999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Solving',
#     'x0': 132.2256,
#     'x1': 164.89343999999994,
#     'top': 299.8278399999999,
#     'doctop': 299.8278399999999,
#     'bottom': 308.9478399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 32.667839999999956,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': '(Intermediate)',
#     'x0': 167.00016,
#     'x1': 226.6358399999999,
#     'top': 299.8278399999999,
#     'doctop': 299.8278399999999,
#     'bottom': 308.9478399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 59.635679999999894,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Certificate',
#     'x0': 229.10735999999986,
#     'x1': 273.0475199999998,
#     'top': 299.8278399999999,
#     'doctop': 299.8278399999999,
#     'bottom': 308.9478399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 43.940159999999935,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'Coursera',
#     'x0': 39.384,
#     'x1': 78.75503999999998,
#     'top': 314.4678399999999,
#     'doctop': 314.4678399999999,
#     'bottom': 323.5878399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 39.37103999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Google',
#     'x0': 81.12624,
#     'x1': 112.32575999999997,
#     'top': 314.4678399999999,
#     'doctop': 314.4678399999999,
#     'bottom': 323.5878399999999,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 31.19951999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'},
#    {'text': 'Data',
#     'x0': 114.67871999999997,
#     'x1': 134.15903999999995,
#     'top': 314.4678399999999,
#     'doctop': 314.4678399999999,
#     'bottom': 323.5878399999999,
#     'upright': True,
# ...
#     'fontname': 'Helvetica'},
#    {'text': 'do',
#     'x0': 150.66719999999998,
#     'x1': 160.78127999999998,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 10.114080000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'sentiment',
#     'x0': 163.13423999999998,
#     'x1': 202.13135999999994,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 38.99711999999997,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'analysis',
#     'x0': 204.62111999999993,
#     'x1': 237.25247999999993,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 32.63136,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'and',
#     'x0': 239.86,
#     'x1': 255.01744000000002,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 15.157440000000008,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'compare',
#     'x0': 257.3704,
#     'x1': 292.19056,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 34.82015999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'them.',
#     'x0': 294.54352,
#     'x1': 317.29536,
#     'top': 593.17784,
#     'doctop': 593.17784,
#     'bottom': 602.29784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 22.751840000000016,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Using',
#     'x0': 42.024,
#     'x1': 65.33471999999999,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 23.31071999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'K-Nearst',
#     'x0': 67.68768,
#     'x1': 103.11695999999999,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 35.42927999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Neighbor',
#     'x0': 105.83471999999999,
#     'x1': 142.23263999999998,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 36.397919999999985,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'and',
#     'x0': 144.70415999999997,
#     'x1': 159.86159999999995,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 15.15743999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'TF-IDF',
#     'x0': 162.21455999999995,
#     'x1': 190.9132,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 28.69864000000004,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'to',
#     'x0': 193.24792,
#     'x1': 200.9452,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 7.697280000000006,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'build',
#     'x0': 203.29816,
#     'x1': 222.28599999999997,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 18.987839999999977,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'a',
#     'x0': 224.6572,
#     'x1': 229.72791999999998,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 5.070719999999994,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'basic',
#     'x0': 232.32711999999998,
#     'x1': 253.21192,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 20.884800000000013,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'recommender',
#     'x0': 255.61048,
#     'x1': 311.16952,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 55.55903999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'system',
#     'x0': 313.64104,
#     'x1': 341.86743999999993,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 28.226399999999956,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'for',
#     'x0': 344.57607999999993,
#     'x1': 355.03671999999995,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 10.460640000000012,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'text.',
#     'x0': 357.5082399999999,
#     'x1': 374.4167199999999,
#     'top': 607.3378399999999,
#     'doctop': 607.3378399999999,
#     'bottom': 616.45784,
#     'upright': True,
#     'height': 9.120000000000118,
#     'width': 16.908479999999997,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Using',
#     'x0': 42.024,
#     'x1': 65.33471999999999,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 23.31071999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'pre-trained',
#     'x0': 67.68768,
#     'x1': 111.14111999999999,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 43.453439999999986,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'model',
#     'x0': 113.51231999999999,
#     'x1': 138.09072,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 24.578400000000016,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'to',
#     'x0': 140.61695999999998,
#     'x1': 148.31423999999998,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 7.697280000000006,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'do',
#     'x0': 150.66719999999998,
#     'x1': 160.78127999999998,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 10.114080000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'text',
#     'x0': 163.13423999999998,
#     'x1': 177.41615999999996,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 14.281919999999985,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'summarization',
#     'x0': 180.13391999999993,
#     'x1': 238.9264,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 58.79248000000007,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'and',
#     'x0': 241.27936,
#     'x1': 256.4368,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 15.157440000000008,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'evaluate.',
#     'x0': 258.78976,
#     'x1': 294.91408,
#     'top': 621.25784,
#     'doctop': 621.25784,
#     'bottom': 630.37784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 36.12432000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Skills',
#     'x0': 27.36,
#     'x1': 58.70400000000001,
#     'top': 645.874,
#     'doctop': 645.874,
#     'bottom': 657.874,
#     'upright': True,
#     'height': 12.0,
#     'width': 31.34400000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica-Bold'}],
#   [{'text': 'Language:',
#     'x0': 42.024,
#     'x1': 84.6424,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 42.618399999999994,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Python',
#     'x0': 87.384,
#     'x1': 115.2456,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 27.861599999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '(pandas,',
#     'x0': 117.6168,
#     'x1': 152.79263999999998,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 35.17583999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'numpy,',
#     'x0': 155.2824,
#     'x1': 184.69439999999994,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 29.41199999999995,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'sklearn,',
#     'x0': 187.18415999999996,
#     'x1': 218.83144000000001,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 31.647280000000052,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'tensoflow,..),',
#     'x0': 221.38,
#     'x1': 272.33344,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 50.95344,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'SQL.',
#     'x0': 274.8232,
#     'x1': 295.21536000000003,
#     'top': 665.67784,
#     'doctop': 665.67784,
#     'bottom': 674.79784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 20.392160000000047,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Visualization:',
#     'x0': 42.024,
#     'x1': 95.17535999999998,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 53.15135999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Power',
#     'x0': 97.728,
#     'x1': 123.09071999999999,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 25.362719999999996,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'BI,',
#     'x0': 125.79024,
#     'x1': 136.71599999999998,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 10.925759999999983,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Python',
#     'x0': 139.20576,
#     'x1': 167.31359999999998,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 28.10783999999998,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '(matplotlib,',
#     'x0': 169.66655999999998,
#     'x1': 213.70703999999995,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 44.040479999999974,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'seaborn).',
#     'x0': 216.19679999999994,
#     'x1': 254.23631999999995,
#     'top': 683.43784,
#     'doctop': 683.43784,
#     'bottom': 692.5578399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 38.03952000000001,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Others:',
#     'x0': 42.024,
#     'x1': 71.65487999999999,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 29.63087999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Excel',
#     'x0': 74.184,
#     'x1': 95.8896,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 21.705600000000004,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': '(pivot',
#     'x0': 98.64384,
#     'x1': 120.59567999999999,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 21.95183999999999,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'table,',
#     'x0': 123.08543999999998,
#     'x1': 145.03727999999998,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 21.951840000000004,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'visualize),',
#     'x0': 147.52703999999997,
#     'x1': 187.49087999999995,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 39.963839999999976,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Word,',
#     'x0': 189.74351999999993,
#     'x1': 214.12127999999996,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 24.377760000000023,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'PowerPoint.',
#     'x0': 216.61103999999995,
#     'x1': 264.9744,
#     'top': 701.19784,
#     'doctop': 701.19784,
#     'bottom': 710.3178399999999,
#     'upright': True,
#     'height': 9.11999999999989,
#     'width': 48.36336000000006,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}],
#   [{'text': 'Pursing:',
#     'x0': 42.024,
#     'x1': 75.27552,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 33.25152,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Statistic,',
#     'x0': 77.784,
#     'x1': 111.73776000000001,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 33.95376,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Machine',
#     'x0': 114.22752,
#     'x1': 148.33632,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 34.1088,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Learning,',
#     'x0': 150.68928,
#     'x1': 188.25455999999994,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 37.565279999999944,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Deep',
#     'x0': 190.74431999999993,
#     'x1': 211.89359999999994,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 21.149280000000005,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'},
#    {'text': 'Learning.',
#     'x0': 214.49279999999993,
#     'x1': 252.23536,
#     'top': 718.98784,
#     'doctop': 718.98784,
#     'bottom': 728.10784,
#     'upright': True,
#     'height': 9.120000000000005,
#     'width': 37.742560000000054,
#     'direction': 'ltr',
#     'fontname': 'Helvetica'}]]]

# %%
section = parser.sections[0]
profile_attrs = ['name', 'email', 'phone', 'location', 'url'] #, 'summary']

def score_feature(text_item, attr):
    score = 0
    for feature, weight in profile_features[attr]:
        if callable(feature):
            if feature(text_item):
                score += weight
        else:
            if feature.match(text_item['text']):
                score += weight
    return score

profile_features = {
    'name': [
        (re.compile(r'^[a-zA-Z\s\.]+$'), 3),
        (lambda item: 'Bold' in item['fontname'], 2),
        (lambda item: item['text'].isupper(), 2),
        (lambda item: '@' in item['text'], -4),
        (lambda item: any(char.isdigit() for char in item['text']), -4),
        (lambda item: ',' in item['text'], -4),
        (lambda item: '/' in item['text'], -4),
    ],
    'email': [
        (re.compile(r'\S+@\S+\.\S+'), 10),
    ],
    'phone': [
        (re.compile(r'\(?\d{3}\)?[\s-]?\d{3}[\s-]?\d{4}'), 10),
    ],
    'location': [
        (re.compile(r'[A-Z][a-z]+, [A-Z]{2}'), 10),
    ],
    'url': [
        (re.compile(r'https?://\S+'), 10),
    ],
}

for item in section[1]:
    print(item["text"], score_feature(item, 'email'))
# Out:
# 0938009294 0
# | 0
# sonbao0901@gmail.com 10
# | 0
# https://github.com/sonbao0901 0
# | 0

# %%
parser.lines
# Out:
# [{'text': 'P H A N T R A N S O N B A O',
#   'fontname': 'Helvetica-Bold',
#   'size': 18.0,
#   'x0': 200.47,
#   'x1': 395.264,
#   'top': 32.545999999999935,
#   'bottom': 50.545999999999935,
#   'upright': True},
#  {'text': '0 9 3 8 0 0 9 2 9 4 | s o n b a o 0 9 0 1 @ g m a i l . c o m | h t t p s : / / g i t h u b . c o m / s o n b a o 0 9 0 1 |',
#   'fontname': 'Helvetica',
#   'size': 11.039999999999964,
#   'x0': 119.33,
#   'x1': 477.0604,
#   'top': 56.065279999999916,
#   'bottom': 67.10527999999988,
#   'upright': True},
#  {'text': 'h t t p s : / / w w w . l i n k e d i n . c o m / i n / p h a n t r a n s o n b a o /',
#   'fontname': 'Helvetica',
#   'size': 11.039999999999964,
#   'x0': 188.95,
#   'x1': 407.02312,
#   'top': 68.78527999999994,
#   'bottom': 79.8252799999999,
#   'upright': True},
#  {'text': 'A b o u t',
#   'fontname': 'Helvetica-Bold',
#   'size': 12.0,
#   'x0': 24.0,
#   'x1': 58.452000000000005,
#   'top': 97.54399999999998,
#   'bottom': 109.54399999999998,
#   'upright': True},
#  {'text': 'I a m a s e n i o r s t u d e n t a t t h e U n i v e r s i t y o f E c o n o m i c s i n H o C h i M i n h C i t y , m a j o r i n g i n D a t a S c i e n c e . W i t h a b i g p a s s i o n f o r w o r k i n g w i t h',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 559.84888,
#   'top': 116.86784,
#   'bottom': 125.98784,
#   'upright': True},
#  {'text': 'd a t a a n d m o d e l s a n d I a m e a g e r t o g a i n m o r e e x p e r i e n c e s f r o m r e a l i s t i c p r o b l e m s i n a c o m p a n y . I a m a d e d i c a t e d p e r s o n a n d a',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 533.19368,
#   'top': 128.89783999999997,
#   'bottom': 138.01783999999998,
#   'upright': True},
#  {'text': 'c o l l a b o r a t i v e t e a m m a t e . I f i n d w o r k i n g w i t h d a t a a n d m o d e l s t o b e b o t h c h a l l e n g i n g a n d r e w a r d i n g , a n d I a m a l w a y s l o o k i n g f o r n e w',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 545.6242400000006,
#   'top': 141.13783999999998,
#   'bottom': 150.25784,
#   'upright': True},
#  {'text': 't h i n g s t o l e a r n a n d i m p r o v e m y s k i l l s , g a i n m o r e v a l u a b l e e x p e r i e n c e s . I a m c u r r e n t l y s e e k i n g a i n t e r n s h i p p o s i t i o n i n t h e f i e l d s o f D a t a',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 556.7987200000001,
#   'top': 153.13783999999998,
#   'bottom': 162.25784,
#   'upright': True},
#  {'text': 'S c i e n c e . I a m e x c i t e d t o b e a p a r t o f y o u r c o m p a n y a n d c o n t r i b u t e m y s k i l l s a n d k n o w l e d g e t o y o u r c o m p a n y .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 457.49624,
#   'top': 165.13783999999998,
#   'bottom': 174.25784,
#   'upright': True},
#  {'text': 'E d u c a t i o n',
#   'fontname': 'Helvetica-Bold',
#   'size': 12.0,
#   'x0': 24.0,
#   'x1': 82.152,
#   'top': 185.654,
#   'bottom': 197.654,
#   'upright': True},
#  {'text': 'U n i v e r s i t y o f E c o n o m i c s , H o C h i M i n h C i t y - V i e t N a m',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 27.84,
#   'x1': 256.57312,
#   'top': 207.87784,
#   'bottom': 216.99784,
#   'upright': True},
#  {'text': 'B a c h e l o r D e g r e e i n D a t a S c i e n c e ( 2 0 2 0 - 2 0 2 4 )',
#   'fontname': 'Helvetica-Oblique',
#   'size': 9.120000000000005,
#   'x0': 27.84,
#   'x1': 212.63415999999998,
#   'top': 221.79783999999995,
#   'bottom': 230.91783999999996,
#   'upright': True},
#  {'text': 'C u m u l a t i v e G P A : 7 . 6 / 1 0',
#   'fontname': 'Helvetica-Oblique',
#   'size': 9.120000000000005,
#   'x0': 27.84,
#   'x1': 124.64263999999999,
#   'top': 236.19783999999993,
#   'bottom': 245.31783999999993,
#   'upright': True},
#  {'text': 'C e r t i f i c a t i o n s',
#   'fontname': 'Helvetica-Bold',
#   'size': 12.0,
#   'x0': 24.0,
#   'x1': 100.67999999999999,
#   'top': 264.874,
#   'bottom': 276.874,
#   'upright': True},
#  {'text': 'H a c k e r R a n k S Q L , P y t h o n ( B a s i c ) C e r t i f i c a t e',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 39.384,
#   'x1': 226.6996799999999,
#   'top': 285.15783999999996,
#   'bottom': 294.27783999999997,
#   'upright': True},
#  {'text': 'H a c k e r R a n k P r o b l e m S o l v i n g ( I n t e r m e d i a t e ) C e r t i f i c a t e',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 39.384,
#   'x1': 273.0475199999998,
#   'top': 299.8278399999999,
#   'bottom': 308.9478399999999,
#   'upright': True},
#  {'text': 'C o u r s e r a G o o g l e D a t a A n a l y t i c s C e r t i f i c a t e',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 39.384,
#   'x1': 223.09727999999984,
#   'top': 314.4678399999999,
#   'bottom': 323.5878399999999,
#   'upright': True},
#  {'text': 'C o u r s e r a I B M D a t a A n a l y s t C e r t i f i c a t e',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.119999999999948,
#   'x0': 39.384,
#   'x1': 201.39704,
#   'top': 329.10784,
#   'bottom': 338.22783999999996,
#   'upright': True},
#  {'text': 'C o u r s e r a I B M D a t a S c i e n c e C e r t i f i c a t e',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 39.384,
#   'x1': 202.7140799999999,
#   'top': 343.74783999999994,
#   'bottom': 352.86783999999994,
#   'upright': True},
#  {'text': 'P r o j e c t s',
#   'fontname': 'Helvetica-Bold',
#   'size': 12.0,
#   'x0': 24.0,
#   'x1': 71.424,
#   'top': 367.38399999999996,
#   'bottom': 379.38399999999996,
#   'upright': True},
#  {'text': 'S u p e r m a r k e t A n a l y s i s A n d D o C u s t o m e r S e g m e n t a t i o n . ( T e a m )',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 294.25024,
#   'top': 394.16783999999996,
#   'bottom': 403.28783999999996,
#   'upright': True},
#  {'text': 'P r e p r o c e s s i n g d a t a w i t h p y t h o n , n o r m a l E D A , u s i n g R F M m e t h o d t o a n a l y s i s a n d l a b e l d a t a .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 409.02536000000003,
#   'top': 409.04783999999995,
#   'bottom': 418.16783999999996,
#   'upright': True},
#  {'text': 'V i s u a l i z e p l o t / c h a r t u s i n g m a t p l o t l i b a n d s e a b o r n .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 237.79,
#   'top': 423.20784,
#   'bottom': 432.32784,
#   'upright': True},
#  {'text': 'D o i n g t e s t s t o s e e i f t h e r e i s a t h e d i f f e r e n c e s o r d e p e n d a n c e s b e t w e e n 2 f e a t u r e .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 366.27536000000003,
#   'top': 437.36783999999994,
#   'bottom': 446.48783999999995,
#   'upright': True},
#  {'text': 'U s i n g d a t a a f t e r d o i n g R F M a n d R F M l a b e l t o p r e d i c t c u s t o m e r s e g m e n t a t i o n w i t h S V M m o d e l a n d e v a l u a t e t h e m o d e l .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 515.15536,
#   'top': 451.28783999999996,
#   'bottom': 460.40783999999996,
#   'upright': True},
#  {'text': 'P r e d i c t i n g W h e t h e r A C l i e n t S u b c r i b e A T e r m D e p o s i t O r N o t W i t h D e e p - L e a r n i n g M o d e l .',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 402.30536,
#   'top': 466.18783999999994,
#   'bottom': 475.30783999999994,
#   'upright': True},
#  {'text': 'P r e p r o c e s s i n g d a t a : c h e c k i n g m i s s i n g v a l u e s , e n c o d i n g , b a l a n c i n g d a t a t a r g e t , … .',
#   'fontname': 'Arial',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 366.1670400000004,
#   'top': 481.0952,
#   'bottom': 490.2152,
#   'upright': True},
#  {'text': 'V i s u a l i z e p l o t / c h a r t u s i n g m a t p l o t l i b a n d s e a b o r n .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 237.61151999999996,
#   'top': 495.22783999999996,
#   'bottom': 504.34783999999996,
#   'upright': True},
#  {'text': 'B u i l d i n g d e e p l e a r n i n g m o d e l w i t h v a r i o u s v a l u e s o f h y p e r p a r a m e t e r s ( l a y e r s , n e u r o n s , b a t c h _ s i z e , … ) .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 449.45904,
#   'top': 509.38784,
#   'bottom': 518.50784,
#   'upright': True},
#  {'text': 'C o m p a r e m o d e l s a n d c h o o s e t h e b e s t m o d e l f o r t h e d a t a .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 271.6747199999999,
#   'top': 523.54784,
#   'bottom': 532.66784,
#   'upright': True},
#  {'text': 'C r a w l D a t a F r o m F a c e b o o k T o D o S e n t i m e n t A n a l y s i s , B u i l d P e r s o n a l R e c o m m e n d e r S y s t e m a n d T e x t S u m m a r i z a t i o n .',
#   'fontname': 'Helvetica-Bold',
#   'size': 9.120000000000005,
#   'x0': 24.0,
#   'x1': 530.27536,
#   'top': 537.46784,
#   'bottom': 546.5878399999999,
#   'upright': True},
#  {'text': 'C r a w l d a t a f r o m F a c e b o o k .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 150.11423999999997,
#   'top': 551.41784,
#   'bottom': 560.53784,
#   'upright': True},
#  {'text': 'P r e p r o c e s s i n g t e x t w i t h n l t k , p y v i .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 175.1396,
#   'top': 565.3378399999999,
#   'bottom': 574.45784,
#   'upright': True},
#  {'text': 'P r e p r o c e s s i n g r e a c t a n d d o b a s i c a n a l y s i s .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 213.1790399999999,
#   'top': 579.25784,
#   'bottom': 588.37784,
#   'upright': True},
#  {'text': 'U s i n g p r e - t r a i n e d m o d e l t o d o s e n t i m e n t a n a l y s i s a n d c o m p a r e t h e m .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 317.29536,
#   'top': 593.17784,
#   'bottom': 602.29784,
#   'upright': True},
#  {'text': 'U s i n g K - N e a r s t N e i g h b o r a n d T F - I D F t o b u i l d a b a s i c r e c o m m e n d e r s y s t e m f o r t e x t .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 374.4167199999999,
#   'top': 607.3378399999999,
#   'bottom': 616.45784,
#   'upright': True},
#  {'text': 'U s i n g p r e - t r a i n e d m o d e l t o d o t e x t s u m m a r i z a t i o n a n d e v a l u a t e .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 294.91408,
#   'top': 621.25784,
#   'bottom': 630.37784,
#   'upright': True},
#  {'text': 'S k i l l s',
#   'fontname': 'Helvetica-Bold',
#   'size': 12.0,
#   'x0': 27.36,
#   'x1': 58.70400000000001,
#   'top': 645.874,
#   'bottom': 657.874,
#   'upright': True},
#  {'text': 'L a n g u a g e : P y t h o n ( p a n d a s , n u m p y , s k l e a r n , t e n s o f l o w , . . ) , S Q L .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 295.21536000000003,
#   'top': 665.67784,
#   'bottom': 674.79784,
#   'upright': True},
#  {'text': 'V i s u a l i z a t i o n : P o w e r B I , P y t h o n ( m a t p l o t l i b , s e a b o r n ) .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 254.23631999999995,
#   'top': 683.43784,
#   'bottom': 692.5578399999999,
#   'upright': True},
#  {'text': 'O t h e r s : E x c e l ( p i v o t t a b l e , v i s u a l i z e ) , W o r d , P o w e r P o i n t .',
#   'fontname': 'Helvetica',
#   'size': 9.120000000000005,
#   'x0': 42.024,
#   'x1': 264.9744,
#   'top': 701.19784,
#   'bottom': 710.3178399999999,
#   'upright': True},
#  {'text': 'P u r s i n g : S t a t i s t i c , M a c h i n e L e a r n i n g , D e e p L e a r n i n g .',
#   'fontname': 'Helvetica',
#   'size': 9.11999999999999,
#   'x0': 42.024,
#   'x1': 252.23536,
#   'top': 718.98784,
#   'bottom': 728.10784,
#   'upright': True}]

# %%
with open('sections.txt', 'w') as f:
    for line in parser.sections[0]:
        f.write(' '.join(item['text'] for item in line))
        f.write('\n\n')

# %%
with pdfplumber.open('../data/cv/CV_SonBao_DS.pdf') as pdf:
    page = pdf.pages[0]
    text_items = page.extract_text_lines(extra_attrs=['fontname'], return_chars=False)
# pdf = pdfplumber.open('../data/cv/CV_SonBao_DS.pdf')
# page = pdf.pages[0]
# img = page.to_image()
# img.draw_rects(text_items)
text_items
# Out:
# [{'text': 'PHAN TRAN SON BAO',
#   'x0': 200.47,
#   'top': 32.545999999999935,
#   'x1': 395.264,
#   'bottom': 50.545999999999935},
#  {'text': '0938009294 | sonbao0901@gmail.com | https://github.com/sonbao0901 |',
#   'x0': 119.33,
#   'top': 56.065279999999916,
#   'x1': 477.0604,
#   'bottom': 67.10527999999988},
#  {'text': 'https://www.linkedin.com/in/phantransonbao/',
#   'x0': 188.95,
#   'top': 68.78527999999994,
#   'x1': 407.02312,
#   'bottom': 79.8252799999999},
#  {'text': 'About',
#   'x0': 24.0,
#   'top': 97.54399999999998,
#   'x1': 58.452000000000005,
#   'bottom': 109.54399999999998},
#  {'text': 'I am a senior student at the University of Economics in Ho Chi Minh City, majoring in Data Science. With a big passion for working with',
#   'x0': 24.0,
#   'top': 116.86784,
#   'x1': 559.84888,
#   'bottom': 125.98784},
#  {'text': 'data and models and I am eager to gain more experiences from realistic problems in a company. I am a dedicated person and a',
#   'x0': 24.0,
#   'top': 128.89783999999997,
#   'x1': 533.19368,
#   'bottom': 138.01783999999998},
#  {'text': 'collaborative teammate. I find working with data and models to be both challenging and rewarding, and I am always looking for new',
#   'x0': 24.0,
#   'top': 141.13783999999998,
#   'x1': 545.6242400000006,
#   'bottom': 150.25784},
#  {'text': 'things to learn and improve my skills, gain more valuable experiences. I am currently seeking a internship position in the fields of Data',
#   'x0': 24.0,
#   'top': 153.13783999999998,
#   'x1': 556.7987200000001,
#   'bottom': 162.25784},
#  {'text': 'Science. I am excited to be a part of your company and contribute my skills and knowledge to your company.',
#   'x0': 24.0,
#   'top': 165.13783999999998,
#   'x1': 457.49624,
#   'bottom': 174.25784},
#  {'text': 'Education',
#   'x0': 24.0,
#   'top': 185.654,
#   'x1': 82.152,
#   'bottom': 197.654},
#  {'text': 'University of Economics, Ho Chi Minh City - Viet Nam',
#   'x0': 27.84,
#   'top': 207.87784,
#   'x1': 256.57312,
#   'bottom': 216.99784},
#  {'text': 'Bachelor Degree in Data Science (2020-2024)',
#   'x0': 27.84,
#   'top': 221.79783999999995,
#   'x1': 212.63415999999998,
#   'bottom': 230.91783999999996},
#  {'text': 'Cumulative GPA: 7.6/10',
#   'x0': 27.84,
#   'top': 236.19783999999993,
#   'x1': 124.64263999999999,
#   'bottom': 245.31783999999993},
#  {'text': 'Certifications',
#   'x0': 24.0,
#   'top': 264.874,
#   'x1': 100.67999999999999,
#   'bottom': 276.874},
#  {'text': 'HackerRank SQL, Python (Basic) Certificate',
#   'x0': 39.384,
#   'top': 285.15783999999996,
#   'x1': 226.6996799999999,
#   'bottom': 294.27783999999997},
#  {'text': 'HackerRank Problem Solving (Intermediate) Certificate',
#   'x0': 39.384,
#   'top': 299.8278399999999,
#   'x1': 273.0475199999998,
#   'bottom': 308.9478399999999},
#  {'text': 'Coursera Google Data Analytics Certificate',
#   'x0': 39.384,
#   'top': 314.4678399999999,
#   'x1': 223.09727999999984,
#   'bottom': 323.5878399999999},
#  {'text': 'Coursera IBM Data Analyst Certificate',
#   'x0': 39.384,
#   'top': 329.10784,
#   'x1': 201.39704,
#   'bottom': 338.22783999999996},
#  {'text': 'Coursera IBM Data Science Certificate',
#   'x0': 39.384,
#   'top': 343.74783999999994,
#   'x1': 202.7140799999999,
#   'bottom': 352.86783999999994},
#  {'text': 'Projects',
#   'x0': 24.0,
#   'top': 367.38399999999996,
#   'x1': 71.424,
#   'bottom': 379.38399999999996},
#  {'text': 'Supermarket Analysis And Do Customer Segmentation. (Team)',
#   'x0': 24.0,
#   'top': 394.16783999999996,
#   'x1': 294.25024,
#   'bottom': 403.28783999999996},
#  {'text': 'Preprocessing data with python, normal EDA, using RFM method to analysis and label data.',
#   'x0': 42.024,
#   'top': 409.04783999999995,
#   'x1': 409.02536000000003,
#   'bottom': 418.16783999999996},
#  {'text': 'Visualize plot/chart using matplotlib and seaborn.',
#   'x0': 42.024,
#   'top': 423.20784,
#   'x1': 237.79,
#   'bottom': 432.32784},
#  {'text': 'Doing tests to see if there is a the differences or dependances between 2 feature.',
#   'x0': 42.024,
#   'top': 437.36783999999994,
#   'x1': 366.27536000000003,
#   'bottom': 446.48783999999995},
#  {'text': 'Using data after doing RFM and RFM label to predict customer segmentation with SVM model and evaluate the model.',
#   'x0': 42.024,
#   'top': 451.28783999999996,
#   'x1': 515.15536,
#   'bottom': 460.40783999999996},
#  {'text': 'Predicting Whether A Client Subcribe A Term Deposit Or Not With Deep-Learning Model.',
#   'x0': 24.0,
#   'top': 466.18783999999994,
#   'x1': 402.30536,
#   'bottom': 475.30783999999994},
#  {'text': 'Preprocessing data: checking missing values, encoding, balancing data target,….',
#   'x0': 42.024,
#   'top': 481.0952,
#   'x1': 366.1670400000004,
#   'bottom': 490.2152},
#  {'text': 'Visualize plot/chart using matplotlib and seaborn.',
#   'x0': 42.024,
#   'top': 495.22783999999996,
#   'x1': 237.61151999999996,
#   'bottom': 504.34783999999996},
#  {'text': 'Building deep learning model with various values of hyperparameters (layers, neurons, batch_size,…).',
#   'x0': 42.024,
#   'top': 509.38784,
#   'x1': 449.45904,
#   'bottom': 518.5352},
#  {'text': 'Compare models and choose the best model for the data.',
#   'x0': 42.024,
#   'top': 523.54784,
#   'x1': 271.6747199999999,
#   'bottom': 532.66784},
#  {'text': 'Crawl Data From Facebook To Do Sentiment Analysis, Build Personal Recommender System and Text Summarization.',
#   'x0': 24.0,
#   'top': 537.46784,
#   'x1': 530.27536,
#   'bottom': 546.5878399999999},
#  {'text': 'Crawl data from Facebook.',
#   'x0': 42.024,
#   'top': 551.41784,
#   'x1': 150.11423999999997,
#   'bottom': 560.53784},
#  {'text': 'Preprocessing text with nltk, pyvi.',
#   'x0': 42.024,
#   'top': 565.3378399999999,
#   'x1': 175.1396,
#   'bottom': 574.45784},
#  {'text': 'Preprocessing react and do basic analysis.',
#   'x0': 42.024,
#   'top': 579.25784,
#   'x1': 213.1790399999999,
#   'bottom': 588.37784},
#  {'text': 'Using pre-trained model to do sentiment analysis and compare them.',
#   'x0': 42.024,
#   'top': 593.17784,
#   'x1': 317.29536,
#   'bottom': 602.29784},
#  {'text': 'Using K-Nearst Neighbor and TF-IDF to build a basic recommender system for text.',
#   'x0': 42.024,
#   'top': 607.3378399999999,
#   'x1': 374.4167199999999,
#   'bottom': 616.45784},
#  {'text': 'Using pre-trained model to do text summarization and evaluate.',
#   'x0': 42.024,
#   'top': 621.25784,
#   'x1': 294.91408,
#   'bottom': 630.37784},
#  {'text': 'Skills',
#   'x0': 27.36,
#   'top': 645.874,
#   'x1': 58.70400000000001,
#   'bottom': 657.874},
#  {'text': 'Language: Python (pandas, numpy, sklearn, tensoflow,..), SQL.',
#   'x0': 42.024,
#   'top': 665.67784,
#   'x1': 295.21536000000003,
#   'bottom': 674.79784},
#  {'text': 'Visualization: Power BI, Python (matplotlib, seaborn).',
#   'x0': 42.024,
#   'top': 683.43784,
#   'x1': 254.23631999999995,
#   'bottom': 692.5578399999999},
#  {'text': 'Others: Excel (pivot table, visualize), Word, PowerPoint.',
#   'x0': 42.024,
#   'top': 701.19784,
#   'x1': 264.9744,
#   'bottom': 710.3178399999999},
#  {'text': 'Pursing: Statistic, Machine Learning, Deep Learning.',
#   'x0': 42.024,
#   'top': 718.98784,
#   'x1': 252.23536,
#   'bottom': 728.10784}]
